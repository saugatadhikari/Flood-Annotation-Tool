# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import Tool

# %%
from utils_elevation import *

# %% [markdown]
# ## Define path to data

# %%
fileid = 0
# ann_path = f"./data/{fileid}trainFeaturesWithElv.npy"
# label_path = f"./data/{fileid}trainLabel.npy"

# ann_path = f"./data/{fileid}testFeaturesWithElv.npy"
# label_path = f"./data/{fileid}testLabel.npy"

ann_path = f"./data/NC_2_big_tr.npy"
label_path = f"./data/test.npy"

# %% [markdown]
# ## Step 1: Run Tool

# %%
# %matplotlib notebook
bs = bbox_select(ann_path, label_path, flood_class=1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_240/3241492652.py in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 2 bs = bbox_select(ann_path, label_path, flood_class=1)
#
# /mnt/e/UAB/Research/HMT/Annotation/Elevation_Annotation_Tool/Flood-Annotation/utils_elevation.py in __init__(self, ann_path, label_path, flood_class)
#      80
#      81         ## Overlay color mask
# ---> 82         self.color_image_overlay = cv2.addWeighted(self.color_image.copy(), 0.7, self.combined_mask.copy(), 0.3, 0.0)
#      83         self.elevation_image_overlay = cv2.addWeighted(self.elevation_image.copy(), 0.7, self.combined_mask.copy(), 0.3, 0.0)
#      84
#
# ...

# %% [markdown]
# # Step 2: Run BFS

# %%
# run bfs on selected point
bs.bfs()

# %% [markdown]
# # Step 3: Plot Result

# %%
# %matplotlib notebook
bs.plot_bfs_result()
# Out:
# (224, 224, 1)
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %% [markdown]
# # Step 4: Commit Result
# **Run this cell only if you want to save the current result, otherwise start again from Step 1**

# %%
bs.commit_result()

# %%
bs.selected_point
# Out:
# (203, 12)

# %%
bs.elevation_map[7][210], bs.elevation_map[75][210]
# Out:
# (0.11597270417946838, 0.22401696562571513)

# %% [markdown]
# # Final Step: After all annotations are completed
# ### Plot trisurface

# %%
bs.plot_trisurface()
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
