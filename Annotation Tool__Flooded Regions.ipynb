# %% [markdown]
# # Use this notebook if you want to annotate Flooded Regions, use the other one if you want to annotate Dry Regions

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import Tool

# %%
from utils_elevation import *

# %% [markdown]
# ## Define path to data

# %%
# path to numpy file which contains an array of image 
# the array has 4 channels, 1st 3 channels are RGB (disaster-time image), 4th channel contains elevation
ann_path = f"./data/99trainFeaturesWithElv.npy"

# path where we want to save the annotated labels as numpy file
# label_path = f"../New_Training_Region_Reach_3/Labels/{fileid}testLabel.npy"
label_path = f"./data/99trainLabel.npy"

# %% [markdown]
# ## Step 1: Run Tool

# %% [markdown]
# ### Select multiple flooded points (DO NOT select dry points!)

# %%
# %matplotlib notebook
bs = bbox_select(ann_path, label_path, flood_class=1)
# Out:
# Button(button_style='danger', description='Draw Polygon', icon='polygon', style=ButtonStyle(), tooltip='Click …
# Button(button_style='info', description='Select Points', icon='point', style=ButtonStyle(), tooltip='Click me'…
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Step 2: Run BFS

# %%
# run bfs on selected point
bs.bfs()

# %% [markdown]
# # Step 3: Plot Result

# %%
# %matplotlib notebook
bs.plot_bfs_result()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Step 4: Commit Result
# **Run this cell only if you want to save the current result, otherwise start again from Step 1**

# %%
bs.commit_result()

# %% [markdown]
# # Final Step: After all annotations are completed
# ### Plot 3d: Red are flood pixels, Blue are dry, and Green are not annotated

# %%
bs.plot_3d()
# Out:
# <img src="data:image/png;base64,..." width="1000">
