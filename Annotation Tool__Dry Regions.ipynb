# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import Tool

# %%
from utils_elevation import *

# %% [markdown]
# ## Define path to data

# %%
fileid = 100
ann_path = f"./data/{fileid}trainFeaturesWithElv.npy"
label_path = f"./data/{fileid}trainLabelNew.npy"

# %% [markdown]
# ## Step 1: Run Tool

# %%
# %matplotlib notebook
bs = bbox_select(ann_path, label_path, flood_class=0)
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
# Check the selected points
# NOTE: its float here, but will be rounded off during BFS in Step 3
bs.selected_points
# Out:
# [[136.4523911248767, 45.80375945922711],
#  [150.1803661519161, 65.53960082847428],
#  [176.16760718781563, 52.570333642968876],
#  [148.5496059370917, 35.090017001635545],
#  [111.90037327504524, 40.72882882142039],
#  [140.09519341560872, 70.61453146628045],
#  [163.21432187672693, 79.07274919595787],
#  [186.33345033784514, 73.43393737617293]]

# %% [markdown]
# # Step 2: Run BFS

# %%
# run bfs on selected point
bs.bfs()

# %% [markdown]
# # Step 3: Plot Result

# %%
# %matplotlib notebook
bs.plot_bfs_result()
# Out:
# <img src="data:image/png;base64,..." width="989.9999785423283">

# %% [markdown]
# # Step 4: Commit Result
# **Run this cell only if you want to save the current result, otherwise start again from Step 1**

# %%
bs.commit_result()

# %% [markdown]
# # Final Step: After all annotations are completed
# ### Plot 3d: Red are flood pixels, Blue are dry

# %%
bs.plot_3d()
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
