# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
fileid = 94
labelpath = f'./data/{fileid}trainLabel.npy'
featurepath = f'./data/{fileid}trainFeaturesWithElv.npy'

labelpath = f'./data/test.npy'
featurepath = f'./data/tiles_8.npy'

# %%
data = np.load(featurepath)
# label = np.load(labelpath)

# %%
data.shape
# Out:
# (224, 224, 4)

# %%
plt.figure(figsize=(10,10))
plt.imshow(data[:,:,:-1].astype('uint8'))

# %%
X = [] 
Y = []
Z = []

for i in range(224):
    for j in range(224):
        X.append(i)
        Y.append(j)
        Z.append(data[i][j][-1])

# %%
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.plot_trisurf(X, Y, Z,
                cmap='viridis', edgecolor='none');

# %%
plt.figure(figsize=(10,10))
plt.imshow(data[:,:,-1], cmap='viridis')

# %%
label = np.load(labelpath)

# %%
plt.figure(figsize=(10,10))
plt.imshow(label.astype('uint8'))
